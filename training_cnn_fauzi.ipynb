# %%
import glob
import numpy as np
import random
import os
import shutil
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from tensorflow.keras import backend
# Out:
# Using TensorFlow backend.

# %%
classifier = Sequential()
classifier.add(Conv2D(64, (3, 3), input_shape = (64, 64, 3), activation = 'relu'))
classifier.add(MaxPooling2D(pool_size = (2, 2)))
classifier.add(Flatten())
classifier.add(Dense(units = 32, activation = 'relu'))
classifier.add(Dense(units = 16, activation = 'relu'))
classifier.add(Dense(units = 1, activation = 'sigmoid'))
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
classifier.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 62, 62, 64)        1792
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 31, 31, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 61504)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                1968160
# _________________________________________________________________
# dense_2 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 1,970,497
# Trainable params: 1,970,497
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255, shear_range = 0.2, zoom_range = 0.2, horizontal_flip = True)
test_datagen = ImageDataGenerator(rescale = 1./255)
training_set = train_datagen.flow_from_directory('C:/Users/Nyx/',target_size = (64, 64), batch_size = 32, class_mode = 'binary')
test_set = test_datagen.flow_from_directory('C:/Users/Nyx/',target_size = (64, 64), batch_size = 32, class_mode = 'binary')
# Out:
# Found 14000 images belonging to 2 classes.
# Found 6000 images belonging to 2 classes.

# %%
for i in range(0, 35):
    classifier.fit_generator(training_set, steps_per_epoch = 400, epochs = 1, validation_data = test_set, validation_steps = 100)
    classifier.save_weights("C:/Users/Nyx/model_"+str(i)+"_ep.h5")

# %% [markdown]
# # tes_deteksi_validasi_epoch

# %%
classifier.load_weights('C:/Users/Nyx/model_20_ep.h5')

# %%
def switch_dict_key_values(this_dict):
    return dict((v,k) for k,v in this_dict.items())

training_set_names = switch_dict_key_values(training_set.class_indices)
print(training_set_names)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e4e0a02fbed0> in <module>
#       2     return dict((v,k) for k,v in this_dict.items())
#       3
# ----> 4 training_set_names = switch_dict_key_values(training_set.class_indices)
#       5 print(training_set_names)
#
# NameError: name 'training_set' is not defined

# %%
from keras.preprocessing import image

daftar_hasil = []
for i in range(0, 2):
    x = training_set_names[i]

    hasil = 0
    for j in range(1, 3001):
        test_image = image.load_img('C:/Users/Nyx/skripsi/cnn_fauzi/old/model/test/' + x + '/' + x + ' ('+ str(j) +').jpg', target_size = (64, 64))
        test_image = image.img_to_array(test_image)
        test_image = np.expand_dims(test_image, axis = 0)
        result = classifier.predict_classes(test_image)
        if training_set_names[i] == training_set_names[result[0][0]]:
            hasil += 1
        #print('C:/Users/Nyx/model/testing/' + x + '/' + x + ' ('+ str(j) +').png', training_set_names[result[0][0]])
    daftar_hasil.append(hasil)

#accuracy_test.append(hasil/79)
#print(i, hasil/79)
print(daftar_hasil)
# Out:
# [2962, 2822]
